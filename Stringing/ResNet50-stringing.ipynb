# %% [markdown]
# #  ResNet50 — Stringing Defect Detection
#
# This notebook trains a **ResNet50** transfer-learning model to classify surface images as **Stringing** or **No Stringing**.
#
# | Step | Description |
# |------|-------------|
# | 1 | Load & preprocess data |
# | 2 | Build the model |
# | 3 | Compile |
# | 4 | Train |
# | 5 | Evaluate |
# | 6 | Save |

# %% [markdown]
# ---
# ##  Imports & Configuration

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'      # suppress TF logs
os.environ['GRPC_VERBOSITY'] = 'ERROR'
os.environ['GLOG_minloglevel'] = '3'

import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_curve,
    auc,
    precision_score,
    recall_score,
    f1_score,
    accuracy_score,
)

# Reproducibility
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)

print(f"TensorFlow version: {tf.__version__}")
print(f"GPUs available: {tf.config.list_physical_devices('GPU')}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777067367.690386   14182 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777067367.719142   14182 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow version: 2.18.0
# GPUs available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ---
# ## Step 1 — Load and Preprocess Data
#
# * Point to `data/` folder (contains `Stringing/` and `No_Stringing/` sub-folders)
# * Resize all images to **224 × 224**
# * Normalize pixels to **[0, 1]**
# * Split: **80 % train / 10 % validation / 10 % test**
# * Apply **augmentation on training set only** (rotation, flip, brightness)
# * Batch size = **32**

# %%
# ---------- paths ----------
DATA_DIR = os.path.join(os.getcwd(), "..", "data")

# ---------- constants ----------
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# ---------- collect all file paths + labels ----------
import glob, random

stringing_files   = sorted(glob.glob(os.path.join(DATA_DIR, "Stringing", "*.jpg")))
no_stringing_files = sorted(glob.glob(os.path.join(DATA_DIR, "No_Stringing", "*.jpg")))

print(f"Stringing images    : {len(stringing_files)}")
print(f"No_Stringing images : {len(no_stringing_files)}")

# Label: Stringing = 1, No_Stringing = 0
all_files  = stringing_files + no_stringing_files
all_labels = [1] * len(stringing_files) + [0] * len(no_stringing_files)

# Shuffle together
combined = list(zip(all_files, all_labels))
random.seed(SEED)
random.shuffle(combined)
all_files, all_labels = zip(*combined)
all_files  = list(all_files)
all_labels = list(all_labels)

total = len(all_files)
train_end = int(0.8 * total)
val_end   = int(0.9 * total)

train_files, train_labels = all_files[:train_end],       all_labels[:train_end]
val_files,   val_labels   = all_files[train_end:val_end], all_labels[train_end:val_end]
test_files,  test_labels  = all_files[val_end:],          all_labels[val_end:]

print(f"\nTrain : {len(train_files)}")
print(f"Val   : {len(val_files)}")
print(f"Test  : {len(test_files)}")
# Out:
# Stringing images    : 2555
# No_Stringing images : 1811
#
# Train : 3492
# Val   : 437
# Test  : 437

# %% [markdown]
# ### 1.1 — Build `tf.data` pipelines with augmentation

# %%
def load_and_preprocess(file_path, label):
    """Read an image file, decode, resize, and normalise to [0,1]."""
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE)
    img = img / 255.0
    return img, label


def augment(img, label):
    """Apply data-augmentation (training set only)."""
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    img = tf.image.random_brightness(img, max_delta=0.2)
    # Random rotation (up to 20 degrees ≈ 0.35 rad)
    # tf.image doesn't have random_rotation, so we use keras layer below
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, label


# --- Augmentation layer for rotation ---
rotation_layer = layers.RandomRotation(factor=0.06, seed=SEED)  # ~20°

def augment_with_rotation(img, label):
    img = rotation_layer(img, training=True)
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    img = tf.image.random_brightness(img, max_delta=0.2)
    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, label


# --- Datasets ---
AUTOTUNE = tf.data.AUTOTUNE

train_ds = (
    tf.data.Dataset.from_tensor_slices((train_files, train_labels))
    .shuffle(len(train_files), seed=SEED)
    .map(load_and_preprocess, num_parallel_calls=AUTOTUNE)
    .map(augment_with_rotation, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

val_ds = (
    tf.data.Dataset.from_tensor_slices((val_files, val_labels))
    .map(load_and_preprocess, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

test_ds = (
    tf.data.Dataset.from_tensor_slices((test_files, test_labels))
    .map(load_and_preprocess, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

print("✅ Data pipelines ready.")
# Out:
# I0000 00:00:1777067371.477366   14182 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6100 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# ✅ Data pipelines ready.

# %% [markdown]
# ### 1.2 — Visualise a batch of training images

# %%
class_names = ["No_Stringing", "Stringing"]

plt.figure(figsize=(14, 6))
for images, labels in train_ds.take(1):
    for i in range(min(10, len(images))):
        ax = plt.subplot(2, 5, i + 1)
        plt.imshow(images[i].numpy())
        plt.title(class_names[int(labels[i])])
        plt.axis("off")
plt.suptitle("Sample Training Images (with augmentation)", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 2 — Build the Model
#
# * Load **ResNet50** pretrained on ImageNet (`include_top=False`)
# * **Freeze** all base layers
# * Add: `GlobalAveragePooling2D → Dense(256, relu) → Dropout(0.3) → Dense(1, sigmoid)`

# %%
# ---------- Load pretrained base ----------
base_model = ResNet50(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet",
)

# Freeze all base layers
base_model.trainable = False

print(f"Base model layers : {len(base_model.layers)}")
print(f"Trainable weights : {len(base_model.trainable_weights)}")

# ---------- Build classification head ----------
inputs = keras.Input(shape=(224, 224, 3), name="input_image")
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D(name="global_avg_pool")(x)
x = layers.Dense(256, activation="relu", name="dense_256")(x)
x = layers.Dropout(0.3, name="dropout_03")(x)
outputs = layers.Dense(1, activation="sigmoid", name="output")(x)

model = keras.Model(inputs, outputs, name="ResNet50_Stringing")
model.summary()
# Out:
# Base model layers : 175
# Trainable weights : 0
# Model: "ResNet50_Stringing"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_avg_pool                 │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_256 (Dense)               │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_03 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,112,513 (91.98 MB)
#  Trainable params: 524,801 (2.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# ---
# ## Step 3 — Compile
#
# * Optimizer: **Adam** (lr = 0.0001)
# * Loss: **binary_crossentropy**
# * Metrics: **accuracy**

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)

print("✅ Model compiled.")
# Out:
# ✅ Model compiled.

# %% [markdown]
# ---
# ## Step 4 — Train
#
# * Epochs: **50**
# * Callbacks:
#   * `EarlyStopping` — patience = 10, monitor `val_loss`
#   * `ReduceLROnPlateau` — factor 0.5, patience 5
#   * `ModelCheckpoint` — save best model

# %%
EPOCHS = 50
BEST_MODEL_PATH = "best_ResNet50_stringing.h5"

cb_list = [
    callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
        verbose=1,
    ),
    callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1,
    ),
    callbacks.ModelCheckpoint(
        filepath=BEST_MODEL_PATH,
        monitor="val_loss",
        save_best_only=True,
        verbose=1,
    ),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=cb_list,
)

print("\n✅ Training complete.")
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777067382.696008   14364 service.cc:148] XLA service 0x7ef20c002720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777067382.696053   14364 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2060 SUPER, Compute Capability 7.5
# I0000 00:00:1777067384.265085   14364 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   3/110 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.3681 - loss: 0.8913
# I0000 00:00:1777067388.724899   14364 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5432 - loss: 0.7212
# Epoch 1: val_loss improved from None to 0.67606, saving model to best_ResNet50_stringing.h5
#
# Epoch 1: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 31s 172ms/step - accuracy: 0.5441 - loss: 0.7096 - val_accuracy: 0.5721 - val_loss: 0.6761 - learning_rate: 1.0000e-04
# Epoch 2/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5667 - loss: 0.6913
# Epoch 2: val_loss improved from 0.67606 to 0.67020, saving model to best_ResNet50_stringing.h5
#
# Epoch 2: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.5601 - loss: 0.6907 - val_accuracy: 0.5721 - val_loss: 0.6702 - learning_rate: 1.0000e-04
# Epoch 3/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5719 - loss: 0.6874
# Epoch 3: val_loss improved from 0.67020 to 0.66760, saving model to best_ResNet50_stringing.h5
#
# Epoch 3: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.5790 - loss: 0.6810 - val_accuracy: 0.5812 - val_loss: 0.6676 - learning_rate: 1.0000e-04
# Epoch 4/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5799 - loss: 0.6747
# Epoch 4: val_loss improved from 0.66760 to 0.66267, saving model to best_ResNet50_stringing.h5
#
# Epoch 4: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.5914 - loss: 0.6687 - val_accuracy: 0.5812 - val_loss: 0.6627 - learning_rate: 1.0000e-04
# Epoch 5/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5834 - loss: 0.6733
# Epoch 5: val_loss improved from 0.66267 to 0.65958, saving model to best_ResNet50_stringing.h5
#
# Epoch 5: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.5902 - loss: 0.6691 - val_accuracy: 0.5744 - val_loss: 0.6596 - learning_rate: 1.0000e-04
# Epoch 6/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6101 - loss: 0.6601
# Epoch 6: val_loss did not improve from 0.65958
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.6042 - loss: 0.6609 - val_accuracy: 0.5767 - val_loss: 0.6622 - learning_rate: 1.0000e-04
# Epoch 7/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6002 - loss: 0.6573
# Epoch 7: val_loss improved from 0.65958 to 0.65332, saving model to best_ResNet50_stringing.h5
#
# Epoch 7: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - accuracy: 0.5991 - loss: 0.6621 - val_accuracy: 0.6110 - val_loss: 0.6533 - learning_rate: 1.0000e-04
# Epoch 8/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6234 - loss: 0.6530
# Epoch 8: val_loss did not improve from 0.65332
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.6100 - loss: 0.6600 - val_accuracy: 0.5835 - val_loss: 0.6578 - learning_rate: 1.0000e-04
# Epoch 9/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5990 - loss: 0.6564
# Epoch 9: val_loss did not improve from 0.65332
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6057 - loss: 0.6562 - val_accuracy: 0.5858 - val_loss: 0.6534 - learning_rate: 1.0000e-04
# Epoch 10/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6227 - loss: 0.6513
# Epoch 10: val_loss improved from 0.65332 to 0.65214, saving model to best_ResNet50_stringing.h5
#
# Epoch 10: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 80ms/step - accuracy: 0.6203 - loss: 0.6522 - val_accuracy: 0.6041 - val_loss: 0.6521 - learning_rate: 1.0000e-04
# Epoch 11/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6096 - loss: 0.6546
# Epoch 11: val_loss improved from 0.65214 to 0.64784, saving model to best_ResNet50_stringing.h5
#
# Epoch 11: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 80ms/step - accuracy: 0.6042 - loss: 0.6533 - val_accuracy: 0.5858 - val_loss: 0.6478 - learning_rate: 1.0000e-04
# Epoch 12/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6125 - loss: 0.6556
# Epoch 12: val_loss improved from 0.64784 to 0.64280, saving model to best_ResNet50_stringing.h5
#
# Epoch 12: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6114 - loss: 0.6555 - val_accuracy: 0.6133 - val_loss: 0.6428 - learning_rate: 1.0000e-04
# Epoch 13/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5908 - loss: 0.6653
# Epoch 13: val_loss did not improve from 0.64280
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.6074 - loss: 0.6535 - val_accuracy: 0.5881 - val_loss: 0.6514 - learning_rate: 1.0000e-04
# Epoch 14/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6207 - loss: 0.6462
# Epoch 14: val_loss did not improve from 0.64280
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.6220 - loss: 0.6467 - val_accuracy: 0.5995 - val_loss: 0.6439 - learning_rate: 1.0000e-04
# Epoch 15/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6085 - loss: 0.6487
# Epoch 15: val_loss improved from 0.64280 to 0.63698, saving model to best_ResNet50_stringing.h5
#
# Epoch 15: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6217 - loss: 0.6476 - val_accuracy: 0.6247 - val_loss: 0.6370 - learning_rate: 1.0000e-04
# Epoch 16/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6318 - loss: 0.6445
# Epoch 16: val_loss did not improve from 0.63698
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6323 - loss: 0.6412 - val_accuracy: 0.5973 - val_loss: 0.6420 - learning_rate: 1.0000e-04
# Epoch 17/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6373 - loss: 0.6420
# Epoch 17: val_loss improved from 0.63698 to 0.63289, saving model to best_ResNet50_stringing.h5
#
# Epoch 17: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.6357 - loss: 0.6430 - val_accuracy: 0.6156 - val_loss: 0.6329 - learning_rate: 1.0000e-04
# Epoch 18/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6488 - loss: 0.6404
# Epoch 18: val_loss improved from 0.63289 to 0.63172, saving model to best_ResNet50_stringing.h5
#
# Epoch 18: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6329 - loss: 0.6413 - val_accuracy: 0.6293 - val_loss: 0.6317 - learning_rate: 1.0000e-04
# Epoch 19/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6438 - loss: 0.6343
# Epoch 19: val_loss did not improve from 0.63172
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.6392 - loss: 0.6389 - val_accuracy: 0.6156 - val_loss: 0.6336 - learning_rate: 1.0000e-04
# Epoch 20/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6465 - loss: 0.6336
# Epoch 20: val_loss did not improve from 0.63172
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6455 - loss: 0.6355 - val_accuracy: 0.5927 - val_loss: 0.6515 - learning_rate: 1.0000e-04
# Epoch 21/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6307 - loss: 0.6374
# Epoch 21: val_loss improved from 0.63172 to 0.62361, saving model to best_ResNet50_stringing.h5
#
# Epoch 21: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.6323 - loss: 0.6389 - val_accuracy: 0.6430 - val_loss: 0.6236 - learning_rate: 1.0000e-04
# Epoch 22/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6452 - loss: 0.6322
# Epoch 22: val_loss improved from 0.62361 to 0.62219, saving model to best_ResNet50_stringing.h5
#
# Epoch 22: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6412 - loss: 0.6361 - val_accuracy: 0.6453 - val_loss: 0.6222 - learning_rate: 1.0000e-04
# Epoch 23/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6530 - loss: 0.6344
# Epoch 23: val_loss did not improve from 0.62219
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6406 - loss: 0.6370 - val_accuracy: 0.6339 - val_loss: 0.6242 - learning_rate: 1.0000e-04
# Epoch 24/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6412 - loss: 0.6370
# Epoch 24: val_loss did not improve from 0.62219
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6435 - loss: 0.6344 - val_accuracy: 0.6224 - val_loss: 0.6267 - learning_rate: 1.0000e-04
# Epoch 25/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6324 - loss: 0.6409
# Epoch 25: val_loss improved from 0.62219 to 0.61492, saving model to best_ResNet50_stringing.h5
#
# Epoch 25: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6432 - loss: 0.6343 - val_accuracy: 0.6499 - val_loss: 0.6149 - learning_rate: 1.0000e-04
# Epoch 26/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6687 - loss: 0.6268
# Epoch 26: val_loss did not improve from 0.61492
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6586 - loss: 0.6284 - val_accuracy: 0.6178 - val_loss: 0.6264 - learning_rate: 1.0000e-04
# Epoch 27/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6534 - loss: 0.6282
# Epoch 27: val_loss improved from 0.61492 to 0.61339, saving model to best_ResNet50_stringing.h5
#
# Epoch 27: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.6360 - loss: 0.6346 - val_accuracy: 0.6545 - val_loss: 0.6134 - learning_rate: 1.0000e-04
# Epoch 28/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6610 - loss: 0.6215
# Epoch 28: val_loss did not improve from 0.61339
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.6564 - loss: 0.6261 - val_accuracy: 0.6384 - val_loss: 0.6161 - learning_rate: 1.0000e-04
# Epoch 29/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6317 - loss: 0.6324
# Epoch 29: val_loss improved from 0.61339 to 0.60732, saving model to best_ResNet50_stringing.h5
#
# Epoch 29: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.6406 - loss: 0.6282 - val_accuracy: 0.6499 - val_loss: 0.6073 - learning_rate: 1.0000e-04
# Epoch 30/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6440 - loss: 0.6261
# Epoch 30: val_loss did not improve from 0.60732
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.6503 - loss: 0.6229 - val_accuracy: 0.6339 - val_loss: 0.6080 - learning_rate: 1.0000e-04
# Epoch 31/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6613 - loss: 0.6237
# Epoch 31: val_loss improved from 0.60732 to 0.60548, saving model to best_ResNet50_stringing.h5
#
# Epoch 31: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.6607 - loss: 0.6236 - val_accuracy: 0.6362 - val_loss: 0.6055 - learning_rate: 1.0000e-04
# Epoch 32/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6671 - loss: 0.6241
# Epoch 32: val_loss improved from 0.60548 to 0.60487, saving model to best_ResNet50_stringing.h5
#
# Epoch 32: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.6607 - loss: 0.6234 - val_accuracy: 0.6522 - val_loss: 0.6049 - learning_rate: 1.0000e-04
# Epoch 33/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6620 - loss: 0.6170
# Epoch 33: val_loss did not improve from 0.60487
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6658 - loss: 0.6187 - val_accuracy: 0.6728 - val_loss: 0.6054 - learning_rate: 1.0000e-04
# Epoch 34/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6554 - loss: 0.6186
# Epoch 34: val_loss did not improve from 0.60487
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6701 - loss: 0.6175 - val_accuracy: 0.6522 - val_loss: 0.6095 - learning_rate: 1.0000e-04
# Epoch 35/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6568 - loss: 0.6239
# Epoch 35: val_loss improved from 0.60487 to 0.59882, saving model to best_ResNet50_stringing.h5
#
# Epoch 35: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6549 - loss: 0.6224 - val_accuracy: 0.6522 - val_loss: 0.5988 - learning_rate: 1.0000e-04
# Epoch 36/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6584 - loss: 0.6172
# Epoch 36: val_loss did not improve from 0.59882
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.6561 - loss: 0.6189 - val_accuracy: 0.6339 - val_loss: 0.6169 - learning_rate: 1.0000e-04
# Epoch 37/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6636 - loss: 0.6113
# Epoch 37: val_loss improved from 0.59882 to 0.59450, saving model to best_ResNet50_stringing.h5
#
# Epoch 37: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.6584 - loss: 0.6156 - val_accuracy: 0.6590 - val_loss: 0.5945 - learning_rate: 1.0000e-04
# Epoch 38/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6712 - loss: 0.6089
# Epoch 38: val_loss improved from 0.59450 to 0.59121, saving model to best_ResNet50_stringing.h5
#
# Epoch 38: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 77ms/step - accuracy: 0.6649 - loss: 0.6142 - val_accuracy: 0.6705 - val_loss: 0.5912 - learning_rate: 1.0000e-04
# Epoch 39/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6631 - loss: 0.6187
# Epoch 39: val_loss did not improve from 0.59121
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.6741 - loss: 0.6090 - val_accuracy: 0.6613 - val_loss: 0.5913 - learning_rate: 1.0000e-04
# Epoch 40/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6632 - loss: 0.6171
# Epoch 40: val_loss did not improve from 0.59121
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6724 - loss: 0.6094 - val_accuracy: 0.6499 - val_loss: 0.5939 - learning_rate: 1.0000e-04
# Epoch 41/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6607 - loss: 0.6115
# Epoch 41: val_loss improved from 0.59121 to 0.58635, saving model to best_ResNet50_stringing.h5
#
# Epoch 41: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6641 - loss: 0.6127 - val_accuracy: 0.6659 - val_loss: 0.5864 - learning_rate: 1.0000e-04
# Epoch 42/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6743 - loss: 0.6069
# Epoch 42: val_loss did not improve from 0.58635
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6670 - loss: 0.6068 - val_accuracy: 0.6888 - val_loss: 0.5913 - learning_rate: 1.0000e-04
# Epoch 43/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6685 - loss: 0.6127
# Epoch 43: val_loss improved from 0.58635 to 0.58222, saving model to best_ResNet50_stringing.h5
#
# Epoch 43: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.6710 - loss: 0.6107 - val_accuracy: 0.6751 - val_loss: 0.5822 - learning_rate: 1.0000e-04
# Epoch 44/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6532 - loss: 0.6179
# Epoch 44: val_loss did not improve from 0.58222
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6604 - loss: 0.6124 - val_accuracy: 0.6568 - val_loss: 0.5885 - learning_rate: 1.0000e-04
# Epoch 45/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6611 - loss: 0.6117
# Epoch 45: val_loss did not improve from 0.58222
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6687 - loss: 0.6055 - val_accuracy: 0.6613 - val_loss: 0.5944 - learning_rate: 1.0000e-04
# Epoch 46/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6774 - loss: 0.5983
# Epoch 46: val_loss did not improve from 0.58222
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.6647 - loss: 0.6083 - val_accuracy: 0.7185 - val_loss: 0.5956 - learning_rate: 1.0000e-04
# Epoch 47/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6393 - loss: 0.6242
# Epoch 47: val_loss improved from 0.58222 to 0.57931, saving model to best_ResNet50_stringing.h5
#
# Epoch 47: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.6621 - loss: 0.6128 - val_accuracy: 0.6728 - val_loss: 0.5793 - learning_rate: 1.0000e-04
# Epoch 48/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6960 - loss: 0.5883
# Epoch 48: val_loss improved from 0.57931 to 0.57914, saving model to best_ResNet50_stringing.h5
#
# Epoch 48: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 80ms/step - accuracy: 0.6824 - loss: 0.5985 - val_accuracy: 0.6682 - val_loss: 0.5791 - learning_rate: 1.0000e-04
# Epoch 49/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6917 - loss: 0.5948
# Epoch 49: val_loss did not improve from 0.57914
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.6764 - loss: 0.6055 - val_accuracy: 0.6636 - val_loss: 0.5886 - learning_rate: 1.0000e-04
# Epoch 50/50
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6690 - loss: 0.6038
# Epoch 50: val_loss improved from 0.57914 to 0.57692, saving model to best_ResNet50_stringing.h5
#
# Epoch 50: finished saving model to best_ResNet50_stringing.h5
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.6755 - loss: 0.6020 - val_accuracy: 0.6522 - val_loss: 0.5769 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 50.
#
# ✅ Training complete.

# %% [markdown]
# ---
# ## Step 5 — Evaluate
#
# * Load best saved model
# * Run on test set
# * Print: **accuracy, precision, recall, F1-score**
# * Plot: **confusion matrix, ROC curve, training/validation accuracy & loss curves**

# %% [markdown]
# ### 5.1 — Load best model & predict on test set

# %%
# Load best checkpoint
best_model = keras.models.load_model(BEST_MODEL_PATH)

# Predict
y_pred_probs = best_model.predict(test_ds).ravel()
y_pred = (y_pred_probs >= 0.5).astype(int)
y_true = np.array(test_labels)

print(f"Test samples : {len(y_true)}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 351ms/step
# Test samples : 437

# %% [markdown]
# ### 5.2 — Classification metrics

# %%
acc  = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred)
rec  = recall_score(y_true, y_pred)
f1   = f1_score(y_true, y_pred)

print("="*50)
print(f"  Accuracy  : {acc:.4f}")
print(f"  Precision : {prec:.4f}")
print(f"  Recall    : {rec:.4f}")
print(f"  F1-Score  : {f1:.4f}")
print("="*50)
print()
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# ==================================================
#   Accuracy  : 0.6842
#   Precision : 0.6658
#   Recall    : 0.9423
#   F1-Score  : 0.7803
# ==================================================
#
#               precision    recall  f1-score   support
#
# No_Stringing       0.78      0.31      0.44       177
#    Stringing       0.67      0.94      0.78       260
#
#     accuracy                           0.68       437
#    macro avg       0.72      0.62      0.61       437
# weighted avg       0.71      0.68      0.64       437

# %% [markdown]
# ### 5.3 — Confusion Matrix

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names,
)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.4 — ROC Curve

# %%
fpr, tpr, _ = roc_curve(y_true, y_pred_probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(7, 5))
plt.plot(fpr, tpr, color="darkorange", lw=2, label=f"ROC curve (AUC = {roc_auc:.4f})")
plt.plot([0, 1], [0, 1], color="navy", lw=1.5, linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC)")
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.5 — Training / Validation Accuracy & Loss Curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Accuracy
axes[0].plot(history.history["accuracy"],    label="Train Accuracy")
axes[0].plot(history.history["val_accuracy"], label="Val Accuracy")
axes[0].set_title("Accuracy")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].legend()
axes[0].grid(alpha=0.3)

# Loss
axes[1].plot(history.history["loss"],     label="Train Loss")
axes[1].plot(history.history["val_loss"], label="Val Loss")
axes[1].set_title("Loss")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.suptitle("Training History", fontsize=14, y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 6 — Save the Model
#
# * Save as **`.h5`** (Keras format)
# * Save as **`SavedModel`** format (for later TFLite conversion)

# %%
# 1) Save as .h5
H5_PATH = "ResNet50_stringing_final.h5"
best_model.save(H5_PATH)
print(f"✅ Model saved as HDF5       → {H5_PATH}")

# 2) Save as SavedModel directory
SAVED_MODEL_DIR = "ResNet50_stringing_savedmodel"
best_model.save(SAVED_MODEL_DIR)
print(f"✅ Model saved as SavedModel → {SAVED_MODEL_DIR}/")
# Out:
# ✅ Model saved as HDF5       → ResNet50_stringing_final.h5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 8
#       4 print(f"✅ Model saved as HDF5       → {H5_PATH}")
#       5
#       6 # 2) Save as SavedModel directory
#       7 SAVED_MODEL_DIR = "ResNet50_stringing_savedmodel"
# ----> 8 best_model.save(SAVED_MODEL_DIR)
#       9 print(f"✅ Model saved as SavedModel → {SAVED_MODEL_DIR}/")
#
# File ~/pfe-env/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/pfe-env/lib/python3.12/site-packages/keras/src/saving/saving_api.py:114, in save_model(model, filepath, overwrite, zipped, **kwargs)
#     110 if str(filepath).endswith((".h5", ".hdf5")):
#     111     return legacy_h5_format.save_model_to_hdf5(
#     112         model, filepath, overwrite, include_optimizer
#     113     )
# --> 114 raise ValueError(
#     115     "Invalid filepath extension for saving. "
#     116     "Please add either a `.keras` extension for the native Keras "
#     117     f"format (recommended) or a `.h5` extension. "
#     118     "Use `model.export(filepath)` if you want to export a SavedModel "
#     119     "for use with TFLite/TFServing/etc. "
#     120     f"Received: filepath={filepath}."
#     121 )
#
# ValueError: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=ResNet50_stringing_savedmodel.

# %% [markdown]
# ---
# ### ✅ Done!
#
# The trained ResNet50 model for **Stringing vs No_Stringing** detection is now saved and ready for deployment or TFLite conversion.
